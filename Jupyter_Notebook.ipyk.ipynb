# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My jupyter notebook on ibm watson studio

# %% [markdown]
# **Muhammad Hashir**

# %% [markdown]
# I am a graphic designer and want to be Data Scientist and Machine learning engineer.

# %% [markdown]
# *I am interested in data science because I can work with large amount of data i am expert in calculus, probablity and statistics and can make best predictions*

# %% [markdown]
# ### In cell 5 code is suppose to do additon between two integers

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# # Numbered List
# # 1- jupyter notebook
# # 2- Python
# # 3- watson studio
#
# # bulleted list
# # . jupyter notebook
# # . python
# # . watson studio
#
# # tables
# | python | programming|
# | jupyter | notebook |
# | watson | studio |
